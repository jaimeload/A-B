# %% [markdown]
# <a href="https://colab.research.google.com/github/jaimeload/A-B/blob/main/A_B_hw1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##1
# ###**Blablacar**
# ####Ключевые метрики:
#
# 1. Количество бронирований - чем больше бронирований, тем больше прибыли с комиссии
#
# 2. Количество платных подписчиков - чем их больше, тем больше постоянной, прогнозируемой прибыли
#
# ##2
# ####Гипотезы:
#
# 1. Добавление тарифных планов на 3, 6, 12 месяцев с соответствующей скидкой привлечёт больше тех подписчиков, кто пользуется сервисом продолжительное время.
#
# 2. Увеличение протяжённости "короткой" поездки привлечёт больше пользователей, так как им не придётся оплачивать комиссию.
#
# 3. Продление длительности пробного периода увеличит количество бронирований и вероятность конвертации пользователей в платных подписчиков в дальнейшем.
#
# 4. Добавление возможности выбора пунктов поездки на интерактивной карте увеличит количество бронирований, потому что так пользователям будет удобнее строить маршрут.
#
# 5. Добавление возможности приглашения друзей в сервис за нулевую комиссию себе и другу увеличит количество активных пользователей, потому что им обоим это выгодно.
