# %% [markdown]
# <a href="https://colab.research.google.com/github/jaimeload/A-B/blob/main/A_B_hw3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [https://jaimeload.github.io/](https://jaimeload.github.io/)

# %% [markdown]
# ![experiment.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![1234.JPG](data:image/jpeg;base64,...)
