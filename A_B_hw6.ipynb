# %% [markdown]
# <a href="https://colab.research.google.com/github/jaimeload/A-B/blob/main/A_B_hw6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##1
# С помощью калькулятора находим необходимое количество человек для проведения теста:

# %% [markdown]
# ![ab61.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# Делим общий размер двух групп на средний трафик в день:

# %%
(61124 * 2) / 20000
# Out:
# 6.1124

# %% [markdown]
# Округляем в большую сторону и получается, что для проведения данного эксперимента потребуется 7 дней.

# %% [markdown]
# ##2
# С помощью калькулятора находим необходимое количество человек для проведения теста:

# %% [markdown]
# ![ab62.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# Делим общий размер двух групп на средний трафик в день:

# %%
(592 * 2) / 4000
# Out:
# 0.296

# %% [markdown]
# Округляем в большую сторону и получается, что для проведения данного эксперимента потребуется 1 день.
