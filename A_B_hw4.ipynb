# %% [markdown]
# <a href="https://colab.research.google.com/github/jaimeload/A-B/blob/main/A_B_hw4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![hw4.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![push.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![rc.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![ia.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![ia1.JPG](data:image/jpeg;base64,...)
