# %% [markdown]
# <a href="https://colab.research.google.com/github/jaimeload/A-B/blob/main/A_B_hw5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##1

# %% [markdown]
# ![ab5.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# Так как 0 не содержится в полученном доверительном интервале, делаем вывод что на заданном уровне значимости статистические различия между группами есть и второй вариант более предпочтителен.

# %% [markdown]
# ##2
# Поскольку размер обеих выборок существенно большой (10000), то лучше всего подойдет Z-критерий сравнения долей. В случае отклонения от нормального распределения применяем поправку Йейтса на непрерывность.
